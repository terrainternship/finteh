# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
from datetime import date
from sklearn.preprocessing import LabelEncoder
import os

# %% [markdown]
# #Основной класс обработки датасета

# %% [markdown]
# *TODO: дописать требования к загружаемым датасетам*

# %%
class Dataset:

    def __init__(self, file_name='', client_class=None,
                 min_amount = 1000, min_year_credit = 2004,
                 pre_processing = False):

        # file_name - имя файла (str) или список файлов (list) с датасетами
        # client_class - класс клиента (int) или список классов клиентов (list)
        # min_amount - минимальная сумма кредита
        # min_year_credit - минимальный год выданного кредита
        # pre_processing - выполнять ли предобработку при загрузке датасетов (можно сделать позже)

        self.__min_amount = min_amount            # минимальная сумма кредита
        self.__min_year_credit = min_year_credit  # минимальный год выданного кредита
        self.__error_init = True                  # ошибка инициализации класса
        self.__datasets = []                      # список загруженных датасетов
        self.df = pd.DataFrame()                  # датафрейм
        self.__classes = client_class == True     # принимает значение True, если датасет был загружен с классами клиентов

        # загрузка датасета (датасетов)
        if file_name:
            self.load(file_name, client_class)

        # предобработка
        if file_name and pre_processing:
            self.pre_processing()

        

    def __len__(self):
        return self.df.shape[0]


    def __str__(self):
        return super().__str__()


    def __repr__(self):
        return super().__repr__()


    def __bool__(self):
        return not self.__error_init


    # Декоратор проверки инициализации класса
    def check_init(func):
        def wrapper(self, *args, **kwargs):
            if self.__error_init:
                raise Exception('Class initialization error')
            else:
                return func(self, *args, **kwargs)
        return wrapper


    @property
    def headers(self):
        """
        Список столбцов
        """

        # если была ошибка при инициализации класса, вызываем ошибку и выходим
        if self.__error_init:
            raise Exception('Class initialization error')

        return list(self.df)


    @check_init
    def save_as_xlsx(self, file_out):
        """
        Сохранение датасета в файл формата XLSX
        """
        self.df.to_excel(file_out)


    @check_init
    def save_as_csv(self, file_out):
        """
        Сохранение датасета в файл формата CSV
        """
        self.df.to_csv(file_out, index=False)


    def load(self, filename:str|list, client_class:int|list):
        """
        Загрузка датасета (датасетов)
        """

        # проверка списка файлов клиента
        if isinstance(filename, str):
            filename = [filename,]

        if not isinstance(filename, list):
            raise Exception('Filename type error')

        # проверка списка классов клиента
        if client_class:
            if isinstance(client_class, int):
                client_class = [client_class,]

            if not isinstance(client_class, list):
                raise Exception('Client class type error')

            if len(filename) != len(client_class):
                raise Exception('The length of the list of filenames and client classes must be equal')

        # TODO: добавить проверку наличия нужных для НС столбцов

        for idx, file in enumerate(filename):
            # проверка расширения файла и загрузка данных
            _, ext = os.path.splitext(file)

            print('loading:', file)

            match ext.lower():

                case '.xlsx':
                    excel_file = pd.ExcelFile(file)
                    df_new = excel_file.parse(excel_file.sheet_names[0])

                case '.csv':
                    df_new = pd.read_csv(file, low_memory=False)
                    # необходимо задать тип данных некоторых столбцов при чтении датасета в формате CSV
                    df_new[['issued']] = self.df[['issued']].astype('datetime64[ns]')

                case _:
                    self.__error_init = True
                    raise Exception('Filename extension error. Must be XLSX or CSV')

            # добавление класса клиентов к датасету
            if client_class:
                df_new['client_class'] = client_class[idx]

            # добавление датасета к уже существующему
            self.df = pd.concat([self.df, df_new])

        # TODO: для ускорения сделать список из датафреймов и в конце объединить их с этим списком

        self.__error_init = False


    @check_init
    def pre_processing(self):
        """
        Предобработка загруженного датасета
        """

        dfc = self.df

        # удаление строк по условиям
        dfc = dfc.drop(dfc[dfc.issued.dt.year < self.__min_year_credit].index)  # минимальная дата выданного кредита
        dfc = dfc.drop(dfc[dfc.amount < self.__min_amount].index)  # минимальная сумма кредита

        # удаление строк с пустым значением в определённых столбцах
        dfc = dfc.drop(dfc[dfc.type_credit==''].index)    # тип кредита
        dfc = dfc.drop(dfc[dfc.status_credit==''].index)  # статус кредита

        # удаление строк с недопустимой валютой (не RUR)
        dfc = dfc.drop(dfc[dfc.currency!='RUB'].index)

        self.df = dfc


    @check_init
    def analysis(self, del_scatter=False):
        """
        Анализ данных датасета:
        - анализ клиентов по качеству кредита
        - добавление столбцов с рейтингом качества кредита

        del_scatter - удаление разбросов (выбросов) в классе датасета
        """

        # Функции обработки столбца days_overdue

        # подсчёт всех записей (1234589ABC, остальные исключаем)
        def count_all_entries(word):
            sum_entries = sum([1 for letter in word if letter in ['1', '2', '3', '4', '5', '8', '9', 'A', 'B', 'C']])
            return 1 if sum_entries == 0 else sum_entries  # если столбец count_all_entries пустой, считаем что запись одна

        # подсчёт записей, указывающие на просрочку
        # исключаем B, т.к. считаем просрочку в 7 дней незначительной,
        # а так же A, т.к. это скорее всего 1я просрочка, хоть и длительная (на обсуждение)
        def count_overdue_entries(word):
            return sum([1 for letter in word if letter in ['2', '3', '4', '5', 'C']])

        # подсчёт записей, ухудшающих рейтинг
        # включен пункт 5 - "более 120 дней", можно добавить другие интервалы
        def count_downgrade_entries(word):
            return sum([1 for letter in word if letter in ['5', '8', '9']])

        # id_list = ds.df['id_nbki'].unique()  # получаем список id клиентов

        # копируем в новый dataframe столбцы, с которыми будем работать
        df = ds.df[['id_nbki', 'status_credit', 'days_overdue']].copy()

        # добавляем столбцы с дополнительными данными
        df['entries_sum'] = 0    # сумма записей о кредитах
        df['overdue_sum'] = 0    # сумма всех просрочек
        df['downgrade_sum'] = 0  # сумма всех ухудшающих рейтинг записей

        # принудительная установка типа столбца
        df[['days_overdue']] = df[['days_overdue']].astype('str')
        df[['entries_sum']] = df[['entries_sum']].astype('int')
        df[['overdue_sum']] = df[['overdue_sum']].astype('int')
        df[['downgrade_sum']] = df[['downgrade_sum']].astype('int')

        # -- Обработка данных

        # обрабатываем столбец days_overdue

        df['entries_sum'] = df['days_overdue'].apply(count_all_entries)  # сумма записей о кредитах
        df['overdue_sum'] = df['days_overdue'].apply(count_overdue_entries)  # сумма всех просрочек
        df['downgrade_sum'] = df['days_overdue'].apply(count_downgrade_entries)  # сумма всех ухудшающих рейтинг записей

        # обрабатываем столбец status_credit

        # если статус кредита "Просрочен", и нет значений в столбце "overdue_sum", прибавляем 1, иначе ничего не прибавляем, т.к. столбец уже обработан ранее
        df.loc[(df['status_credit'] == 'Просрочен') & (df['overdue_sum'] == 0), 'overdue_sum'] += 1

        # если есть соответствующий статус кредита, и нет значений в столбце "downgrade_sum", прибавляем 1
        df.loc[(df['status_credit'].isin(['Банкротство', 'ПринудительноеИсполнение', 'ПроблемыСВозвратом'])) & (df['downgrade_sum'] == 0), 'downgrade_sum'] += 1

        # подсчёт соотношений получившихся значений, выставляем исходя из этого рейтинг

        df_sum = df.groupby('id_nbki').agg({'entries_sum': 'sum', 'overdue_sum': 'sum', 'downgrade_sum': 'sum'}).reset_index()

        df_sum['overdue_prc'] = df_sum['overdue_sum'] / df_sum['entries_sum'] * 100  # процент просроченных платежей
        df_sum[['overdue_prc']] = df_sum[['overdue_prc']].astype('int')

        df_sum['downgrade_prc'] = df_sum['downgrade_sum'] / df_sum['entries_sum'] * 100  # процент снижающих рейтинг платежей
        df_sum[['downgrade_prc']] = df_sum[['downgrade_prc']].astype('int')

        df_sum['grade'] = (df_sum['overdue_sum'] / df_sum['entries_sum']) * 4  # рейтинг (0 - минимальное число просрочек, 3 - максимальное)
        df_sum[['grade']] = df_sum[['grade']].astype('int')

        df_sum = df_sum.assign(downgrade=df_sum['downgrade_sum'] > 0)  # есть ли снижающие рейтинг просрочки (банкротство, проблемы с возвратом, и т.д.)

        # TODO: сделать снижение рейтинга если были серьёзные просрочки
        # TODO: сделать максимальное значение grade=3

        # добавляем рейтинг в исходную таблицу
        self.df = pd.merge(ds.df, df_sum[['id_nbki', 'overdue_prc', 'downgrade_prc', 'grade', 'downgrade']], on='id_nbki')

        # удаляем выбросы в классах датасета (если они были загружены)
        if del_scatter and self.__classes:
            self.df = self.df.query('abs(client_class - grade) != 1')


    def processing(self):
        """
        Подготовка датасета к обработке нейросетью
        """

        # Применение LabelEncoder

        le_gender = LabelEncoder()         # пол
        le_education = LabelEncoder()      # образование
        le_position = LabelEncoder()       # должность
        le_type_credit = LabelEncoder()    # тип кредита
        le_status_credit = LabelEncoder()  # статус кредита

        self.df['le_gender'] = le_gender.fit_transform(self.df['gender'])
        self.df['le_education'] = le_education.fit_transform(self.df['education'])
        self.df['le_position'] = le_position.fit_transform(self.df['position'])
        self.df['le_type_credit'] = le_type_credit.fit_transform(self.df['type_credit'])
        self.df['le_status_credit'] = le_status_credit.fit_transform(self.df['status_credit'])

# %% [markdown]
# #Аналитика

# %% [markdown]
# Выводы после проведённых экспериментов (которые ниже):

# %% [markdown]
# Большой интерес представляет столбец **days_overdue**, т.к. в нём находятся данные по оплате кредита (в отличие от записей, где этот столбец не заполнен)

# %% [markdown]
# 1й вариант записи в столбце days_overdue:
#
#     0 - новый клиент оценка не возможна
#     1 - оплата без просрочек
#     А - просрочка от 1 до 29 дней
#     В - просрочка от 1 до 7 дней
#     С - просрочка от 8 до 29 дней
#     2 - просрочка от 30 до 59 дней
#     3 - просрочка от 60 до 89 дней
#     4 - просрочка от 90 до 119 дней
#     5 - просрочка более 120 дней
#     7 - изменения/дополнения к договору
#     Z - льготный период
#     8 - погашение за счет обеспечения
#     9 - безнадежный долг передано на взыскания
#
# 2й вариант записи в days_overdue и соответствие 1му варианту:
#
#     1-5     - B
#     6-29    - C
#     30-59   - 2
#     60-89   - 3
#     90-119  - 4
#     150-179 - 5
#     180-209 - 5
#     210-239 - 5
#     240 и более - 5
#
# Записи в столбце status_credit, снижающие рейтинг:
#
#     Банкротство
#     ПринудительноеИсполнение
#     ПроблемыСВозвратом

# %% [markdown]
# Можно распарсить данные этого столбца, посчитать количество просрочек, количество вовремя погашенного кредита, а так же количество небольших просрочек (обозначенных **B**). Небольшие просрочки можно сложить с количеством вовремя погашенных кредитов.

# %% [markdown]
# Дополнительно, можно рассмотреть столбец **status_credit**. При налиие статуса **Просрочено**, так же это отметить.

# %% [markdown]
# Далее следует сложить наличия просрочек от столбца **status_credit** и посчитанных просрочек от столбца **days_overdue** и поделить на общее количество записей о кредите (считая все записи в столбце **status_credit**). В итоге получится доля просроченных кредитов. От этого значения можно выставлять рейтинг (так же от 0 до 3).

# %% [markdown]
# Так же следует отдельно выделить записи в столбце **status_credit**, которые выявляют проблемы с кредитом и должны снижать кредитный рейтинг:
# *   Банкротство
# *   ПринудительноеИсполнение
# *   ПроблемыСВозвратом

# %% [markdown]
# Коментарий по поводу кредитов с суммой 0.1 (и обычно обозначенных статусом **ПроблемыСВозвратом**). Проблема в том, что изначально были мелкие остатки на счету после погашения кредита (10 копеек, и почему-то выделенных как отдельный кредит, возможно махинации кредитной организации), но человек об этом не знал, и за время набежали проценты и штрафы. В итоге долг вырастает до десятков тысяч, и человек принципиально платить отказывается. Как считать это в кредитной истории - непонятно. В алгоритме это решается отбрасыванием мелких изначальных сумм кредита.

# %% [markdown]
# Непонятно, как учитывать рейтинг, если имеется **Банкротство**. Можно ли выдавать кредит, в каком размере, и после какого времени после банкротства - надо изучать законодательство. Данных по этому случаю в общих датасетах может не хватать. В текущей модели это просто будет снижать рейтинг на 1.

# %% [markdown]
# В дальнейшем при обучении НС будет иметь смысл учитывать время кредитной истории, и придавать меньшее значение более старым записям, и большее - новым.

# %% [markdown]
# **Гипотеза:**
# *   Сумма меньше 1000 р. смысловой нагрузки не имеет. Нужно установить минимальную сумму кредита, т.к. в датасете есть суммы примерно равные нулю.
# *   Минимальный год кредита в датасете - 2004. Для исключения выбросов то, что меньше, необходимо исключить
# *   Необходимо убрать из выборки строки с нулевыми значениями. Столбцы, данные по которым нужно проверять - необходимо уточнять. На текущий момент - это **type_credit** (тип кредита) и **status_credit** (статус кредита). Возможно надо будет дополнить.
# *   (?) нужно исключить все валюты, кроме рубля. Спорный момент, т.к. кредитная история в долларах - тоже история, хоть в датасете всего одна такая запись.

# %% [markdown]
# #Эксперименты

# %% [markdown]
# ##Корреляция между столбцами

# %%
ds.df.corr()
# Out:
# <ipython-input-85-a4735ac15e99>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ds.df.corr()
#                                      population    amount       psk   balance  \
# population                             1.000000  0.008364  0.007282  0.015134
# amount                                 0.008364  1.000000 -0.015174  0.516383
# psk                                    0.007282 -0.015174  1.000000 -0.005542
# balance                                0.015134  0.516383 -0.005542  1.000000
# current_indebtedness                   0.004031  0.127620 -0.000189  0.023691
# expired                                0.004402  0.092864  0.001763  0.009649
# next_payment                           0.002896  0.059643 -0.000501 -0.001739
# term_indebtedness_body_loan            0.001227  0.674555 -0.010579  0.221758
# term_indebtedness_interest             0.002736  0.101821  0.001024  0.061716
# term_indebtedness_other               -0.002571  0.024413 -0.002281  0.043322
# overdue_indebtedness_body_loan         0.001721  0.199201 -0.005750  0.042854
# overdue_indebtedness_interest          0.000068  0.031245  0.001770  0.001773
# overdue_indebtedness_other             0.001213  0.057598 -0.002706  0.032086
# actual_payments_24_Months              0.001675  0.069333 -0.002984  0.075363
# amount_surety                          0.000135  0.249925 -0.001211  0.099912
# maximum_amount_overdue_indebtedness    0.008116  0.117128 -0.003754  0.034083
# amount_principal_debt_repaid           0.009739  0.431918 -0.015341  0.940990
# availability_support                   0.000434  0.415503 -0.007418  0.248150
#
#                                      current_indebtedness   expired  \
# population                                       0.004031  0.004402
# amount                                           0.127620  0.092864
# psk                                             -0.000189  0.001763
# balance                                          0.023691  0.009649
# current_indebtedness                             1.000000  0.725623
# expired                                          0.725623  1.000000
# next_payment                                     0.516047  0.695897
# term_indebtedness_body_loan                      0.129922  0.054299
# term_indebtedness_interest                       0.016213  0.004106
# term_indebtedness_other                          0.002522  0.002761
# overdue_indebtedness_body_loan                   0.160717  0.213239
# overdue_indebtedness_interest                    0.015106  0.017853
# overdue_indebtedness_other                       0.010549  0.013429
# actual_payments_24_Months                        0.327677  0.139733
# amount_surety                                   -0.000070  0.000098
# maximum_amount_overdue_indebtedness             -0.001526 -0.000933
# amount_principal_debt_repaid                    -0.007157 -0.004374
# availability_support                             0.014980 -0.001054
#
#                                      next_payment  \
# population                               0.002896
# amount                                   0.059643
# psk                                     -0.000501
# balance                                 -0.001739
# current_indebtedness                     0.516047
# expired                                  0.695897
# next_payment                             1.000000
# term_indebtedness_body_loan              0.079371
# term_indebtedness_interest               0.005012
# term_indebtedness_other                  0.001716
# overdue_indebtedness_body_loan           0.002824
# overdue_indebtedness_interest            0.001314
# overdue_indebtedness_other              -0.000352
# actual_payments_24_Months                0.026989
# amount_surety                           -0.000162
# maximum_amount_overdue_indebtedness     -0.000920
# amount_principal_debt_repaid            -0.004312
# availability_support                     0.003631
#
#                                      term_indebtedness_body_loan  \
# population                                              0.001227
# amount                                                  0.674555
# psk                                                    -0.010579
# balance                                                 0.221758
# current_indebtedness                                    0.129922
# expired                                                 0.054299
# next_payment                                            0.079371
# term_indebtedness_body_loan                             1.000000
# term_indebtedness_interest                              0.152630
# term_indebtedness_other                                 0.011359
# overdue_indebtedness_body_loan                          0.005233
# overdue_indebtedness_interest                           0.007164
# overdue_indebtedness_other                             -0.001125
# actual_payments_24_Months                               0.044365
# amount_surety                                           0.278703
# maximum_amount_overdue_indebtedness                     0.011391
# amount_principal_debt_repaid                            0.143190
# availability_support                                    0.357023
#
#                                      term_indebtedness_interest  \
# population                                             0.002736
# amount                                                 0.101821
# psk                                                    0.001024
# balance                                                0.061716
# current_indebtedness                                   0.016213
# expired                                                0.004106
# next_payment                                           0.005012
# term_indebtedness_body_loan                            0.152630
# term_indebtedness_interest                             1.000000
# term_indebtedness_other                                0.008947
# overdue_indebtedness_body_loan                         0.006397
# overdue_indebtedness_interest                          0.014787
# overdue_indebtedness_other                             0.030688
# actual_payments_24_Months                              0.011248
# amount_surety                                          0.045728
# maximum_amount_overdue_indebtedness                   -0.003418
# amount_principal_debt_repaid                           0.033809
# availability_support                                   0.069091
#
#                                      term_indebtedness_other  \
# population                                         -0.002571
# amount                                              0.024413
# psk                                                -0.002281
# balance                                             0.043322
# current_indebtedness                                0.002522
# expired                                             0.002761
# next_payment                                        0.001716
# term_indebtedness_body_loan                         0.011359
# term_indebtedness_interest                          0.008947
# term_indebtedness_other                             1.000000
# overdue_indebtedness_body_loan                      0.048889
# overdue_indebtedness_interest                       0.054708
# overdue_indebtedness_other                          0.046530
# actual_payments_24_Months                           0.000836
# amount_surety                                      -0.000071
# maximum_amount_overdue_indebtedness                -0.000786
# amount_principal_debt_repaid                        0.034813
# availability_support                                0.002468
#
#                                      overdue_indebtedness_body_loan  \
# population                                                 0.001721
# amount                                                     0.199201
# psk                                                       -0.005750
# balance                                                    0.042854
# current_indebtedness                                       0.160717
# expired                                                    0.213239
# next_payment                                               0.002824
# term_indebtedness_body_loan                                0.005233
# term_indebtedness_interest                                 0.006397
# term_indebtedness_other                                    0.048889
# overdue_indebtedness_body_loan                             1.000000
# overdue_indebtedness_interest                              0.141079
# overdue_indebtedness_other                                 0.214769
# actual_payments_24_Months                                  0.062170
# amount_surety                                              0.041369
# maximum_amount_overdue_indebtedness                        0.275609
# amount_principal_debt_repaid                               0.020488
# availability_support                                       0.022839
#
#                                      overdue_indebtedness_interest  \
# population                                                0.000068
# amount                                                    0.031245
# psk                                                       0.001770
# balance                                                   0.001773
# current_indebtedness                                      0.015106
# expired                                                   0.017853
# next_payment                                              0.001314
# term_indebtedness_body_loan                               0.007164
# term_indebtedness_interest                                0.014787
# term_indebtedness_other                                   0.054708
# overdue_indebtedness_body_loan                            0.141079
# overdue_indebtedness_interest                             1.000000
# overdue_indebtedness_other                                0.108559
# actual_payments_24_Months                                 0.001696
# amount_surety                                            -0.000127
# maximum_amount_overdue_indebtedness                      -0.001889
# amount_principal_debt_repaid                             -0.002788
# availability_support                                      0.006854
#
#                                      overdue_indebtedness_other  \
# population                                             0.001213
# amount                                                 0.057598
# psk                                                   -0.002706
# balance                                                0.032086
# current_indebtedness                                   0.010549
# expired                                                0.013429
# next_payment                                          -0.000352
# term_indebtedness_body_loan                           -0.001125
# term_indebtedness_interest                             0.030688
# term_indebtedness_other                                0.046530
# overdue_indebtedness_body_loan                         0.214769
# overdue_indebtedness_interest                          0.108559
# overdue_indebtedness_other                             1.000000
# actual_payments_24_Months                             -0.000174
# amount_surety                                         -0.000228
# maximum_amount_overdue_indebtedness                   -0.001297
# amount_principal_debt_repaid                           0.019120
# availability_support                                   0.012280
#
#                                      actual_payments_24_Months  amount_surety  \
# population                                            0.001675       0.000135
# amount                                                0.069333       0.249925
# psk                                                  -0.002984      -0.001211
# balance                                               0.075363       0.099912
# current_indebtedness                                  0.327677      -0.000070
# expired                                               0.139733       0.000098
# next_payment                                          0.026989      -0.000162
# term_indebtedness_body_loan                           0.044365       0.278703
# term_indebtedness_interest                            0.011248       0.045728
# term_indebtedness_other                               0.000836      -0.000071
# overdue_indebtedness_body_loan                        0.062170       0.041369
# overdue_indebtedness_interest                         0.001696      -0.000127
# overdue_indebtedness_other                           -0.000174      -0.000228
# actual_payments_24_Months                             1.000000      -0.000203
# amount_surety                                        -0.000203       1.000000
# maximum_amount_overdue_indebtedness                  -0.001895      -0.000368
# amount_principal_debt_repaid                         -0.008889       0.077795
# availability_support                                  0.008108       0.132070
#
#                                      maximum_amount_overdue_indebtedness  \
# population                                                      0.008116
# amount                                                          0.117128
# psk                                                            -0.003754
# balance                                                         0.034083
# current_indebtedness                                           -0.001526
# expired                                                        -0.000933
# next_payment                                                   -0.000920
# term_indebtedness_body_loan                                     0.011391
# term_indebtedness_interest                                     -0.003418
# term_indebtedness_other                                        -0.000786
# overdue_indebtedness_body_loan                                  0.275609
# overdue_indebtedness_interest                                  -0.001889
# overdue_indebtedness_other                                     -0.001297
# actual_payments_24_Months                                      -0.001895
# amount_surety                                                  -0.000368
# maximum_amount_overdue_indebtedness                             1.000000
# amount_principal_debt_repaid                                    0.020710
# availability_support                                            0.001874
#
#                                      amount_principal_debt_repaid  \
# population                                               0.009739
# amount                                                   0.431918
# psk                                                     -0.015341
# balance                                                  0.940990
# current_indebtedness                                    -0.007157
# expired                                                 -0.004374
# next_payment                                            -0.004312
# term_indebtedness_body_loan                              0.143190
# term_indebtedness_interest                               0.033809
# term_indebtedness_other                                  0.034813
# overdue_indebtedness_body_loan                           0.020488
# overdue_indebtedness_interest                           -0.002788
# overdue_indebtedness_other                               0.019120
# actual_payments_24_Months                               -0.008889
# amount_surety                                            0.077795
# maximum_amount_overdue_indebtedness                      0.020710
# amount_principal_debt_repaid                             1.000000
# availability_support                                     0.198220
#
#                                      availability_support
# population                                       0.000434
# amount                                           0.415503
# psk                                             -0.007418
# balance                                          0.248150
# current_indebtedness                             0.014980
# expired                                         -0.001054
# next_payment                                     0.003631
# term_indebtedness_body_loan                      0.357023
# term_indebtedness_interest                       0.069091
# term_indebtedness_other                          0.002468
# overdue_indebtedness_body_loan                   0.022839
# overdue_indebtedness_interest                    0.006854
# overdue_indebtedness_other                       0.012280
# actual_payments_24_Months                        0.008108
# amount_surety                                    0.132070
# maximum_amount_overdue_indebtedness              0.001874
# amount_principal_debt_repaid                     0.198220
# availability_support                             1.000000

# %%
import seaborn as sns
corr = ds.df.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <ipython-input-83-f8a7944771bb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = ds.df.corr()
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.matshow(ds.df.corr())
plt.show()
# Out:
# <ipython-input-86-23c71a369720>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(ds.df.corr())

# %%
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-87-ce9744728a5b>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_c4e40_row0_col0, #T_c4e40_row1_col1, #T_c4e40_row2_col2, #T_c4e40_row3_col3, #T_c4e40_row4_col4, #T_c4e40_row5_col5, #T_c4e40_row6_col6, #T_c4e40_row7_col7, #T_c4e40_row8_col8, #T_c4e40_row9_col9, #T_c4e40_row10_col10, #T_c4e40_row11_col11, #T_c4e40_row12_col12, #T_c4e40_row13_col13, #T_c4e40_row14_col14, #T_c4e40_row15_col15, #T_c4e40_row16_col16, #T_c4e40_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c4e40_row0_col1, #T_c4e40_row0_col2, #T_c4e40_row0_col3, #T_c4e40_row4_col8, #T_c4e40_row4_col17, #T_c4e40_row5_col11, #T_c4e40_row8_col4, #T_c4e40_row8_col13, #T_c4e40_row9_col7, #T_c4e40_row11_col4, #T_c4e40_row11_col5, #T_c4e40_row12_col17, #T_c4e40_row15_col7, #T_c4e40_row16_col12, #T_c4e40_row17_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c4e40_row0_col4, #T_c4e40_row0_col5, #T_c4e40_row0_col7, #T_c4e40_row0_col13, #T_c4e40_row1_col0, #T_c4e40_row2_col0, #T_c4e40_row3_col2, #T_c4e40_row4_col16, #T_c4e40_row5_col16, #T_c4e40_row6_col8, #T_c4e40_row6_col10, #T_c4e40_row6_col16, #T_c4e40_row6_col17, #T_c4e40_row7_col10, #T_c4e40_row7_col11, #T_c4e40_row8_col5, #T_c4e40_row8_col6, #T_c4e40_row8_col9, #T_c4e40_row9_col4, #T_c4e40_row9_col13, #T_c4e40_row9_col17, #T_c4e40_row10_col2, #T_c4e40_row10_col8, #T_c4e40_row11_col13, #T_c4e40_row12_col7, #T_c4e40_row12_col13, #T_c4e40_row14_col13, #T_c4e40_row15_col0, #T_c4e40_row15_col2, #T_c4e40_row15_col17, #T_c4e40_row17_col6, #T_c4e40_row17_col11 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c4e40_row0_col6, #T_c4e40_row0_col8, #T_c4e40_row0_col10, #T_c4e40_row0_col12, #T_c4e40_row0_col17, #T_c4e40_row2_col4, #T_c4e40_row2_col5, #T_c4e40_row2_col8, #T_c4e40_row2_col11, #T_c4e40_row2_col13, #T_c4e40_row3_col11, #T_c4e40_row4_col0, #T_c4e40_row4_col9, #T_c4e40_row5_col0, #T_c4e40_row5_col8, #T_c4e40_row5_col9, #T_c4e40_row5_col17, #T_c4e40_row6_col0, #T_c4e40_row6_col9, #T_c4e40_row6_col11, #T_c4e40_row7_col2, #T_c4e40_row8_col0, #T_c4e40_row9_col5, #T_c4e40_row9_col6, #T_c4e40_row10_col0, #T_c4e40_row10_col6, #T_c4e40_row11_col3, #T_c4e40_row11_col6, #T_c4e40_row12_col6, #T_c4e40_row13_col0, #T_c4e40_row13_col11, #T_c4e40_row13_col16, #T_c4e40_row14_col4, #T_c4e40_row14_col5, #T_c4e40_row14_col6, #T_c4e40_row15_col4, #T_c4e40_row15_col13, #T_c4e40_row17_col2, #T_c4e40_row17_col9, #T_c4e40_row17_col15 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c4e40_row0_col9, #T_c4e40_row0_col11, #T_c4e40_row0_col14, #T_c4e40_row1_col2, #T_c4e40_row2_col1, #T_c4e40_row2_col3, #T_c4e40_row2_col6, #T_c4e40_row2_col7, #T_c4e40_row2_col9, #T_c4e40_row2_col10, #T_c4e40_row2_col12, #T_c4e40_row2_col14, #T_c4e40_row2_col15, #T_c4e40_row2_col16, #T_c4e40_row2_col17, #T_c4e40_row3_col6, #T_c4e40_row4_col14, #T_c4e40_row4_col15, #T_c4e40_row5_col14, #T_c4e40_row5_col15, #T_c4e40_row6_col3, #T_c4e40_row6_col12, #T_c4e40_row6_col14, #T_c4e40_row6_col15, #T_c4e40_row7_col0, #T_c4e40_row7_col12, #T_c4e40_row8_col15, #T_c4e40_row9_col0, #T_c4e40_row9_col14, #T_c4e40_row9_col15, #T_c4e40_row11_col0, #T_c4e40_row11_col14, #T_c4e40_row11_col15, #T_c4e40_row12_col0, #T_c4e40_row12_col14, #T_c4e40_row12_col15, #T_c4e40_row13_col9, #T_c4e40_row13_col12, #T_c4e40_row13_col14, #T_c4e40_row13_col15, #T_c4e40_row14_col0, #T_c4e40_row14_col9, #T_c4e40_row14_col11, #T_c4e40_row14_col12, #T_c4e40_row14_col15, #T_c4e40_row15_col5, #T_c4e40_row15_col6, #T_c4e40_row15_col8, #T_c4e40_row15_col9, #T_c4e40_row15_col11, #T_c4e40_row15_col12, #T_c4e40_row15_col14, #T_c4e40_row16_col2, #T_c4e40_row16_col4, #T_c4e40_row16_col5, #T_c4e40_row16_col6, #T_c4e40_row16_col11, #T_c4e40_row16_col13, #T_c4e40_row17_col0, #T_c4e40_row17_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c4e40_row0_col15, #T_c4e40_row3_col5, #T_c4e40_row4_col2, #T_c4e40_row4_col12, #T_c4e40_row5_col3, #T_c4e40_row6_col2, #T_c4e40_row7_col9, #T_c4e40_row7_col15, #T_c4e40_row8_col10, #T_c4e40_row9_col2, #T_c4e40_row9_col8, #T_c4e40_row11_col16, #T_c4e40_row11_col17, #T_c4e40_row12_col2, #T_c4e40_row13_col2, #T_c4e40_row13_col8, #T_c4e40_row13_col17, #T_c4e40_row14_col2, #T_c4e40_row16_col0, #T_c4e40_row17_col12 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c4e40_row0_col16, #T_c4e40_row1_col9, #T_c4e40_row16_col10, #T_c4e40_row16_col15 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col3, #T_c4e40_row4_col6, #T_c4e40_row6_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c4e40_row1_col4, #T_c4e40_row7_col4, #T_c4e40_row17_col14 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col6, #T_c4e40_row3_col8, #T_c4e40_row5_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col7, #T_c4e40_row7_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_c4e40_row1_col8, #T_c4e40_row14_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col10, #T_c4e40_row16_col17 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col11, #T_c4e40_row3_col12, #T_c4e40_row8_col12, #T_c4e40_row12_col8, #T_c4e40_row12_col16 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col12 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col13, #T_c4e40_row8_col17 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col14, #T_c4e40_row3_col17, #T_c4e40_row17_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c4e40_row1_col15 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c4e40_row1_col16, #T_c4e40_row16_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c4e40_row1_col17 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c4e40_row3_col0, #T_c4e40_row4_col11, #T_c4e40_row5_col2, #T_c4e40_row5_col12, #T_c4e40_row8_col2, #T_c4e40_row8_col11, #T_c4e40_row10_col7, #T_c4e40_row11_col2, #T_c4e40_row11_col7, #T_c4e40_row11_col8, #T_c4e40_row12_col4, #T_c4e40_row12_col5, #T_c4e40_row17_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c4e40_row3_col4, #T_c4e40_row4_col3, #T_c4e40_row10_col17, #T_c4e40_row13_col6, #T_c4e40_row17_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col9, #T_c4e40_row11_col1, #T_c4e40_row14_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col10, #T_c4e40_row8_col14, #T_c4e40_row8_col16, #T_c4e40_row9_col3, #T_c4e40_row9_col12, #T_c4e40_row9_col16, #T_c4e40_row10_col3, #T_c4e40_row12_col9, #T_c4e40_row14_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col13, #T_c4e40_row7_col6, #T_c4e40_row13_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col15, #T_c4e40_row6_col13, #T_c4e40_row9_col1, #T_c4e40_row10_col16, #T_c4e40_row12_col3, #T_c4e40_row15_col16, #T_c4e40_row16_col8, #T_c4e40_row16_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c4e40_row3_col16 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c4e40_row4_col1, #T_c4e40_row10_col11, #T_c4e40_row13_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c4e40_row4_col5, #T_c4e40_row5_col4 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_c4e40_row4_col7, #T_c4e40_row14_col17 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c4e40_row4_col10, #T_c4e40_row10_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c4e40_row4_col13, #T_c4e40_row13_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c4e40_row5_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c4e40_row5_col6, #T_c4e40_row6_col5 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_c4e40_row5_col10, #T_c4e40_row10_col5, #T_c4e40_row10_col12 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c4e40_row5_col13, #T_c4e40_row11_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c4e40_row6_col1, #T_c4e40_row10_col13, #T_c4e40_

# %% [markdown]
# ###Выводы
# Максимальная корреляция:
#
# `0.94 - balance - amount_principal_debt_repaid`
#
# `0.73 - expired - current_indebtedness`
#
# `0.70 - expired - next_payment`
#
# `0.67 - amount - term_indebtedness_body_loan`
#
# `0.52 - balance - amount`
#
# `0.52 - next_payment - current_indebtedness`
#
# `0.43 - amount - amount_principal_debt_repaid`
#
# `0.42 - amount - availability_support`
#
# `0.36 - availability_support - term_indebtedness_body_loan`
#
# `0.33 - current_indebtedness - actual_payments_24_Months`
#
# `0.28 - amount_surety - term_indebtedness_body_loan`
#
# `0.28 - overdue_indebtedness_body_loan - maximum_amount_overdue_indebtedness`

# %% [markdown]
# ##Проверка и отладка класса обработки датасета

# %%
path = '/content/drive/MyDrive/UII/Fintex/'
file_input1_xls = 'dataset1_02.xlsx'
file_input2_xls = 'dataset2_02.xlsx'
file_output_xls = 'output.xlsx'
file_output_csv = 'output.csv'

file_in1 = f'{path}{file_input1_xls}'
file_in2 = f'{path}{file_input2_xls}'

# %%
# загрузка датасетов (без классов)
ds = Dataset(file_name=[file_in1, file_in2], pre_processing=False)
# Out:
# loading: /content/drive/MyDrive/UII/Fintex/dataset1_02.xlsx
# loading: /content/drive/MyDrive/UII/Fintex/dataset2_02.xlsx

# %%
# загрузка датасетов с классами клиентов
ds = Dataset(file_name=[file_in1, file_in2], client_class=[0, 3], pre_processing=False)
# Out:
# loading: /content/drive/MyDrive/UII/Fintex/dataset1_02.xlsx
# loading: /content/drive/MyDrive/UII/Fintex/dataset2_02.xlsx

# %%
# Предобработка. Удаляет строки с нулевыми значениями, выбросы данных и т.д. (необходимо запускать перед анализом)
ds.pre_processing()

# %%
# Анализ. Проверяет, выявляет и удаляет (при значении del_scatter = True) выбросы в классах клиентов
ds.analysis()  # по умолчанию del_scatter = False

# %%
ds = Dataset(file_name=[file_in1, file_in2], client_class=[0, 3])
ds.analysis(del_scatter=True)
# Out:
# loading: /content/drive/MyDrive/UII/Fintex/dataset1_02.xlsx
# loading: /content/drive/MyDrive/UII/Fintex/dataset2_02.xlsx

# %%
# Подготовка датасета к обработке нейросетью
ds.processing()

# %%
ds.df
# Out:
#                   region_name        city_name  population date of birth  \
# 0       Новосибирская область    г.  Барабинск     29122.0    1980-07-28
# 1       Новосибирская область    г.  Барабинск     29122.0    1980-07-28
# 2       Новосибирская область    г.  Барабинск     29122.0    1980-07-28
# 3       Новосибирская область    г.  Барабинск     29122.0    1980-07-28
# 4       Новосибирская область    г.  Барабинск     29122.0    1980-07-28
# ...                       ...              ...         ...           ...
# 234663    Ставропольский край  г. Невинномысск    116884.0    1946-09-15
# 234664    Ставропольский край  г. Невинномысск    116884.0    1946-09-15
# 234665    Ставропольский край  г. Невинномысск    116884.0    1946-09-15
# 234666    Ставропольский край  г. Невинномысск    116884.0    1946-09-15
# 234667    Ставропольский край  г. Невинномысск    116884.0    1946-09-15
#
#          gender          education                  position    dt_nbki  \
# 0       Женский             Высшее  работник бюджетной сферы 2023-03-05
# 1       Женский             Высшее  работник бюджетной сферы 2023-03-05
# 2       Женский             Высшее  работник бюджетной сферы 2023-03-05
# 3       Женский             Высшее  работник бюджетной сферы 2023-03-05
# 4       Женский             Высшее  работник бюджетной сферы 2023-03-05
# ...         ...                ...                       ...        ...
# 234663  Женский  СреднеТехническое                 пенсионер 2020-10-30
# 234664  Женский  СреднеТехническое                 пенсионер 2020-10-30
# 234665  Женский  СреднеТехническое                 пенсионер 2020-10-30
# 234666  Женский  СреднеТехническое                 пенсионер 2020-10-30
# 234667  Женский  СреднеТехническое                 пенсионер 2020-10-30
#
#                                      id_nbki     issued  ...  client_class  \
# 0       27ab5815-bb2d-11ed-b80d-3cfdfed12971 2013-10-07  ...             0
# 1       27ab5815-bb2d-11ed-b80d-3cfdfed12971 2013-11-06  ...             0
# 2       27ab5815-bb2d-11ed-b80d-3cfdfed12971 2016-04-05  ...             0
# 3       27ab5815-bb2d-11ed-b80d-3cfdfed12971 2016-04-16  ...             0
# 4       27ab5815-bb2d-11ed-b80d-3cfdfed12971 2016-05-13  ...             0
# ...                                      ...        ...  ...           ...
# 234663  392179ad-1ab6-11eb-80c7-f4034344a6bd 2014-09-02  ...             3
# 234664  392179ad-1ab6-11eb-80c7-f4034344a6bd 2012-10-07  ...             3
# 234665  392179ad-1ab6-11eb-80c7-f4034344a6bd 2012-08-01  ...             3
# 234666  392179ad-1ab6-11eb-80c7-f4034344a6bd 2011-01-24  ...             3
# 234667  392179ad-1ab6-11eb-80c7-f4034344a6bd 2011-04-08  ...             3
#
#        overdue_prc downgrade_prc grade downgrade le_gender  le_education  \
# 0               15             0     0     False         0             0
# 1               15             0     0     False         0             0
# 2               15             0     0     False         0             0
# 3               15             0     0     False         0             0
# 4               15             0     0     False         0             0
# ...            ...           ...   ...       ...       ...           ...
# 234663           0             0     0     False         0             4
# 234664           0             0     0     False         0             4
# 234665           0             0     0     False         0             4
# 234666           0             0     0     False         0             4
# 234667           0             0     0     False         0             4
#
#         le_position  le_type_credit  le_status_credit
# 0                 7              10                 7
# 1                 7              17                 7
# 2                 7              11                12
# 3                 7              11                12
# 4                 7              11                12
# ...             ...             ...               ...
# 234663            5              17                12
# 234664            5              17                12
# 234665            5              17                12
# 234666            5              17                12
# 234667            5              10                12
#
# [234668 rows x 51 columns]

# %%
ds.headers
# Out:
# ['region_name',
#  'city_name',
#  'population',
#  'date of birth',
#  'gender',
#  'education',
#  'position',
#  'dt_nbki',
#  'id_nbki',
#  'issued',
#  'amount',
#  'currency',
#  'type_credit',
#  'status_credit',
#  'period',
#  'period_interest',
#  'psk',
#  'balance',
#  'current_indebtedness',
#  'expired',
#  'days_overdue',
#  'next_payment',
#  'last_payment',
#  'updated',
#  'term_indebtedness_body_loan',
#  'term_indebtedness_interest',
#  'term_indebtedness_other',
#  'overdue_indebtedness_body_loan',
#  'overdue_indebtedness_interest',
#  'overdue_indebtedness_other',
#  'actual_payments_24_Months',
#  'volume_commitment',
#  'amount_surety',
#  'surety_period',
#  'source_information',
#  'maximum_amount_overdue_indebtedness',
#  'date_credit_state',
#  'beginning_days_delinquency_counting',
#  'type_debt',
#  'amount_principal_debt_repaid',
#  'availability_support',
#  'client_class',
#  'overdue_prc',
#  'downgrade_prc',
#  'grade',
#  'downgrade',
#  'le_gender',
#  'le_education',
#  'le_position',
#  'le_type_credit',
#  'le_status_credit']

# %% [markdown]
# Следующие шаги:
# * сделать преобразование записи просроченных кредитов вида 1-6, 7-29 в A, B
# * определить, какие столбцы нужны для дальнейшей работы в Autokeras

# %% [markdown]
# ##Autokeras

# %%
import pandas as pd
from IPython.display import display
from keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# копируем только те столбцы, которые принимают участие в обучении НС
df = ds.df[['id_nbki', 'population', 'le_gender', 'le_education', 'le_position', 'date of birth',
            'amount', 'le_type_credit', 'le_status_credit', 'psk', 'balance', 'current_indebtedness',
            'expired', 'days_overdue', 'next_payment', 'term_indebtedness_body_loan',
            'term_indebtedness_interest', 'term_indebtedness_other', 'overdue_indebtedness_body_loan',
            'overdue_indebtedness_interest', 'overdue_indebtedness_other', 'actual_payments_24_Months',
            'amount_principal_debt_repaid']].copy()
# df = df.drop('Date', axis=1)

# %%
# нормировка столбцов Weekly_Sales, Temperature, Fuel_Price, CPI и Unemployment
scaler = MinMaxScaler()
df[['population', 'amount', 'psk', 'balance', 'current_indebtedness',
    'expired', 'next_payment', 'term_indebtedness_body_loan',
    'term_indebtedness_interest', 'term_indebtedness_other', 'overdue_indebtedness_body_loan',
    'overdue_indebtedness_interest', 'overdue_indebtedness_other', 'actual_payments_24_Months',
    'amount_principal_debt_repaid']] = \
    scaler.fit_transform(df[['population', 'amount', 'psk', 'balance', 'current_indebtedness',
    'expired', 'next_payment', 'term_indebtedness_body_loan',
    'term_indebtedness_interest', 'term_indebtedness_other', 'overdue_indebtedness_body_loan',
    'overdue_indebtedness_interest', 'overdue_indebtedness_other', 'actual_payments_24_Months',
    'amount_principal_debt_repaid']])

# %%
# TODO: добавить обработку (через LabelEncoder) столбец type_debt

# %%
# подсчет строк с отсутствующими значениями
df.isna().sum()
# Out:
# id_nbki                                0
# population                            22
# le_gender                              0
# le_education                           0
# le_position                            0
# date of birth                          0
# amount                               419
# le_type_credit                         0
# le_status_credit                       0
# psk                                  419
# balance                              419
# current_indebtedness                 419
# expired                              419
# days_overdue                      173179
# next_payment                         419
# term_indebtedness_body_loan          419
# term_indebtedness_interest           419
# term_indebtedness_other              419
# overdue_indebtedness_body_loan       419
# overdue_indebtedness_interest        419
# overdue_indebtedness_other           419
# actual_payments_24_Months            419
# amount_principal_debt_repaid         419
# dtype: int64

# %%
# выделение признаков и целевой переменной
x = df.copy()
y = ds.df['client_class'].replace(3, 1)

# %%
# разделение датасета на обучающую и проверочную выборки
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# вывод размеров обучающей и проверочной выборок
print(f'Размер обучающей выборки: {X_train.shape[0]}')
print(f'Размер проверочной выборки: {X_test.shape[0]}')
# Out:
# Размер обучающей выборки: 187734
# Размер проверочной выборки: 46934

# %%
# !pip install autokeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autokeras
#   Downloading autokeras-1.1.0-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from autokeras) (23.1)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from autokeras) (2.12.0)
# Collecting keras-tuner>=1.1.0 (from autokeras)
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 20.8 MB/s eta 0:00:00
# Collecting keras-nlp>=0.4.0 (from autokeras)
#   Downloading keras_nlp-0.5.2-py3-none-any.whl (527 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.7/527.7 kB 49.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from autokeras) (1.5.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.4.0->autokeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.4.0->autokeras) (1.22.4)
# Collecting tensorflow-text (from keras-nlp>=0.4.0->autokeras)
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 115.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner>=1.1.0->autokeras) (2.27.1)
# Collecting kt-legacy (from keras-tuner>=1.1.0->autokeras)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->autokeras) (0.32.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->autokeras) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->autokeras) (2022.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->autokeras) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.8.0->autokeras) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.8.0->autokeras) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (2.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (3.4)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text->keras-nlp>=0.4.0->autokeras) (0.13.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->autokeras) (3.2.2)
# Installing collected packages: kt-legacy, keras-tuner, tensorflow-text, keras-nlp, autokeras
# Successfully installed autokeras-1.1.0 keras-nlp-0.5.2 keras-tuner-1.3.5 kt-legacy-1.0.5 tensorflow-text-2.12.1

# %%
import autokeras as ak

# %%
# инициализация класса автоматического машинного обучения
reg2 = ak.StructuredDataRegressor(
    overwrite=True,
    max_trials=50,
    tuner="hyperband",
    loss='mean_squared_error',
    metrics=['mean_absolute_error'],
    project_name='weekly_sales_forecast2'
)

# поиск лучшей модели
reg2.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test))
# Out:
# Trial 50 Complete [00h 02m 45s]
# val_loss: 0.1636195033788681
#
# Best val_loss So Far: 0.10400569438934326
# Total elapsed time: 02h 24m 43s
# Epoch 1/20
# 5867/5867 [==============================] - 15s 2ms/step - loss: 0.1086 - mean_absolute_error: 0.2220 - val_loss: 0.1073 - val_mean_absolute_error: 0.2124
# Epoch 2/20
# 5867/5867 [==============================] - 14s 2ms/step - loss: 0.0928 - mean_absolute_error: 0.1900 - val_loss: 0.1016 - val_mean_absolute_error: 0.2150
# Epoch 3/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0880 - mean_absolute_error: 0.1842 - val_loss: 0.1022 - val_mean_absolute_error: 0.2015
# Epoch 4/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0909 - mean_absolute_error: 0.1906 - val_loss: 0.0960 - val_mean_absolute_error: 0.2001
# Epoch 5/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0854 - mean_absolute_error: 0.1788 - val_loss: 0.0948 - val_mean_absolute_error: 0.2049
# Epoch 6/20
# 5867/5867 [==============================] - 14s 2ms/step - loss: 0.0831 - mean_absolute_error: 0.1756 - val_loss: 0.0942 - val_mean_absolute_error: 0.1949
# Epoch 7/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0813 - mean_absolute_error: 0.1730 - val_loss: 0.0929 - val_mean_absolute_error: 0.2005
# Epoch 8/20
# 5867/5867 [==============================] - 14s 2ms/step - loss: 0.0806 - mean_absolute_error: 0.1712 - val_loss: 0.0918 - val_mean_absolute_error: 0.1967
# Epoch 9/20
# 5867/5867 [==============================] - 14s 2ms/step - loss: 0.0803 - mean_absolute_error: 0.1708 - val_loss: 0.0922 - val_mean_absolute_error: 0.2000
# Epoch 10/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0792 - mean_absolute_error: 0.1690 - val_loss: 0.0911 - val_mean_absolute_error: 0.2058
# Epoch 11/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0793 - mean_absolute_error: 0.1690 - val_loss: 0.0945 - val_mean_absolute_error: 0.2166
# Epoch 12/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0792 - mean_absolute_error: 0.1682 - val_loss: 0.0926 - val_mean_absolute_error: 0.2154
# Epoch 13/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0784 - mean_absolute_error: 0.1672 - val_loss: 0.0907 - val_mean_absolute_error: 0.1993
# Epoch 14/20
# 5867/5867 [==============================] - 14s 2ms/step - loss: 0.0780 - mean_absolute_error: 0.1663 - val_loss: 0.0897 - val_mean_absolute_error: 0.2008
# Epoch 15/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0777 - mean_absolute_error: 0.1659 - val_loss: 0.0893 - val_mean_absolute_error: 0.1940
# Epoch 16/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0774 - mean_absolute_error: 0.1653 - val_loss: 0.0900 - val_mean_absolute_error: 0.1968
# Epoch 17/20
# 5867/5867 [==============================] - 15s 3ms/step - loss: 0.0773 - mean_absolute_error: 0.1650 - val_loss: 0.0898 - val_mean_absolute_error: 0.1909
# Epoch 18/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0772 - mean_absolute_error: 0.1650 - val_loss: 0.0924 - val_mean_absolute_error: 0.2065
# Epoch 19/20
# 5867/5867 [==============================] - 13s 2ms/step - loss: 0.0770 - mean_absolute_error: 0.1643 - val_loss: 0.0926 - val_mean_absolute_error: 0.2213
# Epoch 20/20
# 5867/5867 [==============================] - 14s 2ms/step - loss: 0.0772 - mean_absolute_error: 0.1647 - val_loss: 0.0888 - val_mean_absolute_error: 0.2001
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %% [markdown]
# здесь колаб остановился и не вывел лучшую модель

# %%
best_model2 = reg2.export_model()
# Получите архитектуру модели в виде JSON строки
model_json2 = best_model2.to_json()

print("Model architecture:")
print(model_json2)

# %%
best_model2.summary()

# %% [markdown]
# необходимы последующие эксперименты, в т.ч. с другими методами Autokeras, а так же проверить ещё теории по обработке датасета
